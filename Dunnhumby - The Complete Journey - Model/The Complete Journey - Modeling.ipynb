# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, Ridge
import joblib
from joblib import dump

# %%
df_data=pd.read_csv("./data/all_tables_combined.csv")

# %%
df_data.head(3)
# Out:
#    household_key  PRODUCT_ID  QUANTITY  SALES_VALUE  STORE_ID  RETAIL_DISC  \
# 0           2305      873203         1         1.67       414        -1.02
# 1           2305      873203         1         1.79       414        -0.90
# 2           2305      873203         1         1.89       414         0.00
#
#    TRANS_TIME  COUPON_DISC  COUPON_MATCH_DISC description  ...  \
# 0        1300          0.0                0.0       TypeA  ...
# 1        1220          0.0                0.0       TypeA  ...
# 2        1111          0.0                0.0       TypeA  ...
#
#    HOMEOWNER_DESC   HH_COMP_DESC  HOUSEHOLD_SIZE_DESC  KID_CATEGORY_DESC  \
# 0       Homeowner  Single Female                    1       None/Unknown
# 1       Homeowner  Single Female                    1       None/Unknown
# 2       Homeowner  Single Female                    1       None/Unknown
#
#    MANUFACTURER DEPARTMENT    BRAND COMMODITY_DESC SUB_COMMODITY_DESC  \
# 0            69    GROCERY  Private         CHEESE    SHREDDED CHEESE
# 1            69    GROCERY  Private         CHEESE    SHREDDED CHEESE
# 2            69    GROCERY  Private         CHEESE    SHREDDED CHEESE
#
#   CURR_SIZE_OF_PRODUCT
# 0                 8 OZ
# 1                 8 OZ
# 2                 8 OZ
#
# [3 rows x 28 columns]

# %%
df_s_parent=df_data[df_data['HH_COMP_DESC']=="1 Adult Kids"]

# %%
df_s_parent['NUM_DAYS']=df_s_parent['END_DAY'] - df_s_parent['START_DAY'] + 1
df_s_parent.drop(['START_DAY','END_DAY','DAY','COUPON_UPC','HH_COMP_DESC','CAMPAIGN','household_key','PRODUCT_ID'], axis=1, inplace=True)
# Out:
# <ipython-input-292-051c3faac5bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s_parent['NUM_DAYS']=df_s_parent['END_DAY'] - df_s_parent['START_DAY'] + 1
# /home/user-1711/venv/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_s_parent.head(2)
# Out:
#      QUANTITY  SALES_VALUE  STORE_ID  RETAIL_DISC  TRANS_TIME  COUPON_DISC  \
# 472         1         1.00       403        -0.50        1142          0.0
# 473         1         5.45       403        -2.19        1142          0.0
#
#      COUPON_MATCH_DISC description AGE_DESC MARITAL_STATUS_CODE  ...  \
# 472                0.0       TypeA    25-34                   B  ...
# 473                0.0       TypeA    25-34                   B  ...
#
#     HOMEOWNER_DESC HOUSEHOLD_SIZE_DESC KID_CATEGORY_DESC MANUFACTURER  \
# 472      Homeowner                   3                 2           69
# 473      Homeowner                   3                 2         2877
#
#      DEPARTMENT     BRAND COMMODITY_DESC SUB_COMMODITY_DESC  \
# 472  MEAT-PCKGD   Private      LUNCHMEAT                HAM
# 473        MEAT  National           BEEF        CHOICE BEEF
#
#     CURR_SIZE_OF_PRODUCT NUM_DAYS
# 472                 6 OZ       56
# 473                            56
#
# [2 rows x 21 columns]

# %%
sns.pairplot(df_s_parent)

# %%
df_s_parent
# Out:
#         QUANTITY  SALES_VALUE  STORE_ID  RETAIL_DISC  TRANS_TIME  COUPON_DISC  \
# 472            1         1.00       403        -0.50        1142          0.0
# 473            1         5.45       403        -2.19        1142          0.0
# 474            2        10.24       403        -4.11        1040          0.0
# 475            1         6.42       403        -2.58        1844          0.0
# 476            3        11.97       403         0.00        1142          0.0
# ...          ...          ...       ...          ...         ...          ...
# 112013         1         2.99       304        -0.20        1456          0.0
# 112014         1         2.50       304        -0.19        1456          0.0
# 112015         1         2.99       304        -1.00        1456          0.0
# 112016         1         2.50       304        -0.79        1456          0.0
# 112017         1         2.50       304        -0.19        1456          0.0
#
#         COUPON_MATCH_DISC description AGE_DESC MARITAL_STATUS_CODE  ...  \
# 472                   0.0       TypeA    25-34                   B  ...
# 473                   0.0       TypeA    25-34                   B  ...
# 474                   0.0       TypeA    25-34                   B  ...
# 475                   0.0       TypeA    25-34                   B  ...
# 476                   0.0       TypeA    25-34                   B  ...
# ...                   ...         ...      ...                 ...  ...
# 112013                0.0       TypeA    35-44                   B  ...
# 112014                0.0       TypeA    35-44                   B  ...
# 112015                0.0       TypeA    35-44                   B  ...
# 112016                0.0       TypeA    35-44                   B  ...
# 112017                0.0       TypeA    35-44                   B  ...
#
#        HOMEOWNER_DESC HOUSEHOLD_SIZE_DESC KID_CATEGORY_DESC MANUFACTURER  \
# 472         Homeowner                   3                 2           69
# 473         Homeowner                   3                 2         2877
# 474         Homeowner                   3                 2         2877
# 475         Homeowner                   3                 2         2877
# 476         Homeowner                   3                 2         5154
# ...               ...                 ...               ...          ...
# 112013      Homeowner                   4                3+          236
# 112014      Homeowner                   4                3+          135
# 112015      Homeowner                   4                3+           93
# 112016      Homeowner                   4                3+         1598
# 112017      Homeowner                   4                3+          135
#
#         DEPARTMENT     BRAND      COMMODITY_DESC SUB_COMMODITY_DESC  \
# 472     MEAT-PCKGD   Private           LUNCHMEAT                HAM
# 473           MEAT  National                BEEF        CHOICE BEEF
# 474           MEAT  National                BEEF        CHOICE BEEF
# 475           MEAT  National                BEEF        CHOICE BEEF
# 476           MEAT  National                BEEF              ANGUS
# ...            ...       ...                 ...                ...
# 112013     GROCERY  National  FROZEN BREAD/DOUGH      FRZN BISCUITS
# 112014     GROCERY  National       FRZN POTATOES  FRZN FRENCH FRIES
# 112015  MEAT-PCKGD  National      DINNER SAUSAGE      SMOKED/COOKED
# 112016  MEAT-PCKGD  National         FROZEN MEAT          CORN DOGS
# 112017     GROCERY  National       FRZN POTATOES  FRZN FRENCH FRIES
#
#        CURR_SIZE_OF_PRODUCT NUM_DAYS
# 472                    6 OZ       56
# 473                               56
# 474                               56
# 475                               56
# 476                    1 LB       56
# ...                     ...      ...
# 112013              20.8 OZ       56
# 112014                28 OZ       56
# 112015                16 OZ       48
# 112016              9.87 OZ       56
# 112017                26 OZ       56
#
# [6356 rows x 21 columns]

# %%
df_s_parent['SUB_COMMODITY_DESC'].value_counts().head(10)
# Out:
# FRZN MULTI SERVE ENTREES ALL      164
# FRZN BAGGED VEGETABLES - PLAIN    162
# YOGURT NOT MULTI-PACKS            158
# PREMIUM                           158
# FRZN SS PREMIUM ENTREES/DNRS/T    152
# SNACKS/APPETIZERS                 147
# FLUID MILK WHITE ONLY             140
# DAIRY CASE 100% PURE JUICE - O    132
# SOFT DRINKS 12/18&15PK CAN CAR    123
# SS ECONOMY ENTREES/DINNERS ALL    122
# Name: SUB_COMMODITY_DESC, dtype: int64

# %%
df_s_parent[df_s_parent['SUB_COMMODITY_DESC'].str.contains('MILK')]['SUB_COMMODITY_DESC'].unique()
# Out:
# array(['FLUID MILK WHITE ONLY', 'INFANT FORMULA MILK BASE',
#        'MISCELLANEOUS MILK', 'CHOCOLATE MILK'], dtype=object)

# %%
df_s_parent=df_s_parent[(df_s_parent['SUB_COMMODITY_DESC']=='FLUID MILK WHITE ONLY') | (df_s_parent['SUB_COMMODITY_DESC']=='MISCELLANEOUS MILK') | (df_s_parent['SUB_COMMODITY_DESC']=='CHOCOLATE MILK')]

# %%
df_s_parent.columns.values
# Out:
# array(['QUANTITY', 'SALES_VALUE', 'STORE_ID', 'RETAIL_DISC', 'TRANS_TIME',
#        'COUPON_DISC', 'COUPON_MATCH_DISC', 'description', 'AGE_DESC',
#        'MARITAL_STATUS_CODE', 'INCOME_DESC', 'HOMEOWNER_DESC',
#        'HOUSEHOLD_SIZE_DESC', 'KID_CATEGORY_DESC', 'MANUFACTURER',
#        'DEPARTMENT', 'BRAND', 'COMMODITY_DESC', 'SUB_COMMODITY_DESC',
#        'CURR_SIZE_OF_PRODUCT', 'NUM_DAYS'], dtype=object)

# %%
df_s_parent.drop(['STORE_ID','TRANS_TIME','description', 'AGE_DESC', 'MARITAL_STATUS_CODE', 'INCOME_DESC', 'HOMEOWNER_DESC', 'HOUSEHOLD_SIZE_DESC', 'KID_CATEGORY_DESC', 'DEPARTMENT', 'COMMODITY_DESC', 'SUB_COMMODITY_DESC'], axis=1, inplace=True)
# Out:
# /home/user-1711/venv/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_s_parent
# Out:
#         QUANTITY  SALES_VALUE  RETAIL_DISC  COUPON_DISC  COUPON_MATCH_DISC  \
# 3440           1         2.49         0.00          0.0                0.0
# 3441           1         1.67        -0.82          0.0                0.0
# 3442           2         4.98         0.00          0.0                0.0
# 3443           1         2.49         0.00          0.0                0.0
# 3444           1         1.67        -0.82          0.0                0.0
# ...          ...          ...          ...          ...                ...
# 98393          1         1.00        -0.79          0.0                0.0
# 98394          2         3.88         0.00          0.0                0.0
# 107281         1         1.89         0.00          0.0                0.0
# 108984         1         2.79         0.00          0.0                0.0
# 111895         1         2.00         0.00          0.0                0.0
#
#         MANUFACTURER     BRAND CURR_SIZE_OF_PRODUCT  NUM_DAYS
# 3440              69   Private                 1 GA        48
# 3441              69   Private                 1 GA        48
# 3442              69   Private                 1 GA        48
# 3443              69   Private                 1 GA        48
# 3444              69   Private                 1 GA        48
# ...              ...       ...                  ...       ...
# 98393             69   Private                             48
# 98394             69   Private                             48
# 107281           709  National                16 OZ        49
# 108984            69   Private                 1 GA        49
# 111895          5423  National                             48
#
# [175 rows x 9 columns]

# %%
df_s_parent['CURR_SIZE_OF_PRODUCT'].value_counts()
# Out:
#          86
# 1 GA     60
# 1 PT     20
# 16 OZ     6
# 1 QT      2
# PT        1
# Name: CURR_SIZE_OF_PRODUCT, dtype: int64

# %%
def label_to_volume(label):
    volume=int()
    if label=='1 GA':
        volume=128
    elif label=='1 PT':
        volume=16
    elif label=='16 OZ':
        volume=16
    elif label=='1 QT':
        volume=32
    elif label=='PT':
        volume=16
        
    return volume

vect_label_to_volume=np.vectorize(label_to_volume)

# %%
df_s_parent['VOLUME']=vect_label_to_volume(df_s_parent['CURR_SIZE_OF_PRODUCT'])
df_s_parent.head()
# Out:
# <ipython-input-304-8d7fce3a0822>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s_parent['VOLUME']=vect_label_to_volume(df_s_parent['CURR_SIZE_OF_PRODUCT'])
#       QUANTITY  SALES_VALUE  RETAIL_DISC  COUPON_DISC  COUPON_MATCH_DISC  \
# 3440         1         2.49         0.00          0.0                0.0
# 3441         1         1.67        -0.82          0.0                0.0
# 3442         2         4.98         0.00          0.0                0.0
# 3443         1         2.49         0.00          0.0                0.0
# 3444         1         1.67        -0.82          0.0                0.0
#
#       MANUFACTURER    BRAND CURR_SIZE_OF_PRODUCT  NUM_DAYS  VOLUME
# 3440            69  Private                 1 GA        48     128
# 3441            69  Private                 1 GA        48     128
# 3442            69  Private                 1 GA        48     128
# 3443            69  Private                 1 GA        48     128
# 3444            69  Private                 1 GA        48     128

# %%
sales=df_s_parent['SALES_VALUE']

# %%
df_s_parent_features=df_s_parent.drop('SALES_VALUE', axis=1)

# %%
dummy=pd.get_dummies(df_s_parent_features['BRAND'])
df_s_parent_features=pd.concat([df_s_parent_features,dummy], axis=1)
df_s_parent_features
# Out:
#         QUANTITY  RETAIL_DISC  COUPON_DISC  COUPON_MATCH_DISC  MANUFACTURER  \
# 3440           1         0.00          0.0                0.0            69
# 3441           1        -0.82          0.0                0.0            69
# 3442           2         0.00          0.0                0.0            69
# 3443           1         0.00          0.0                0.0            69
# 3444           1        -0.82          0.0                0.0            69
# ...          ...          ...          ...                ...           ...
# 98393          1        -0.79          0.0                0.0            69
# 98394          2         0.00          0.0                0.0            69
# 107281         1         0.00          0.0                0.0           709
# 108984         1         0.00          0.0                0.0            69
# 111895         1         0.00          0.0                0.0          5423
#
#            BRAND CURR_SIZE_OF_PRODUCT  NUM_DAYS  VOLUME  National  Private
# 3440     Private                 1 GA        48     128         0        1
# 3441     Private                 1 GA        48     128         0        1
# 3442     Private                 1 GA        48     128         0        1
# 3443     Private                 1 GA        48     128         0        1
# 3444     Private                 1 GA        48     128         0        1
# ...          ...                  ...       ...     ...       ...      ...
# 98393    Private                             48       0         0        1
# 98394    Private                             48       0         0        1
# 107281  National                16 OZ        49      16         1        0
# 108984   Private                 1 GA        49     128         0        1
# 111895  National                             48       0         1        0
#
# [175 rows x 11 columns]

# %%
df_s_parent_features.drop(['BRAND','CURR_SIZE_OF_PRODUCT'], axis=1, inplace=True)

# %%
sns.heatmap(df_s_parent_features.corr())
# Out:
# <AxesSubplot:>

# %%
X=df_s_parent_features
y=sales

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, random_state = 22)

# %%
sscaler=StandardScaler()

# %%
X_train_scaled=sscaler.fit_transform(X_train)
X_test_scaled=sscaler.transform(X_test)

# %%
lasso=Lasso(alpha=0.0001)
lasso.fit(X_train_scaled,y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
y_preds=lasso.predict(X_test_scaled)
plt.scatter(y_test,y_preds)

# %%
pd.DataFrame({'features':X.columns, 'coefs':lasso.coef_}).sort_values(by='coefs', ascending=False)
# Out:
#             features     coefs
# 0           QUANTITY  1.519231
# 1        RETAIL_DISC  0.897966
# 6             VOLUME  0.204519
# 7           National  0.045366
# 2        COUPON_DISC  0.000000
# 3  COUPON_MATCH_DISC  0.000000
# 8            Private -0.000000
# 4       MANUFACTURER -0.029958
# 5           NUM_DAYS -0.411510

# %%
cross_val_score(lasso, X_train_scaled,y_train)
# Out:
# array([0.79785837, 0.866427  , 0.80647737, 0.8735066 , 0.60973561])

# %%
cross_val_score(lasso, X_test_scaled,y_test)
# Out:
# array([0.70124705, 0.86640583, 0.82661028, 0.66966709, 0.83007296])

# %% [markdown]
# Next let's take the columns whose coefficients have a magnitude over 0.01. We'll try to estimate using ridge instead of lasso and see hot it performs.
#
# NB: REMOVE THE UNECESSARY COLUMNS FROM THE FEATURE MATRIX. NOT DONE YET.

# %%
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
# Out:
# Ridge()

# %%
y_ridge_preds=ridge.predict(X_test_scaled)

# %%
cross_val_score(ridge, X_test_scaled,y_test)
# Out:
# array([0.72576678, 0.85006201, 0.80306079, 0.62838151, 0.81694092])

# %%
plt.scatter(y_test,y_ridge_preds)

# %%
dump(lasso, 'spf_model.joblib')
# Out:
# ['spf_model.joblib']
